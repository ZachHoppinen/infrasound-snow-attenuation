# %%
import numpy as np
import pandas as pd
import os

# %%
fp = '../../banner/data/cube_12162021/211202/12050000.BE4'

# %%
arr = np.fromfile(fp)

# %%
arr.shape
# Out:
# (28162713,)

# %%
dt_arr = pd.to_datetime(arr)

# %%
sorted(dt_arr)
# Out:
# [Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1969-12-31 23:59:59.999999998'),
#  Timestamp('1970-01-01 00:00:00'),
#  NaT,
#  Timestamp('1970-01-01 00:00:00'),
#  Timestamp('1970-01-01 00:00:00'),
#  NaT,
#  Timestamp('1970-01-01 00:00:00'),
#  Timestamp('1970-01-01 00:00:00'),
#  NaT,
#  NaT,
#  Timestamp('1970-01-01 00:00:00'),
#  Timestamp('1970-01-01 00:00:00'),
#  Timestamp('1970-01-01 00:00:00'),
#  Timestamp('1970-01-01 00:00:00'),
#  Timestamp('1970-01-01 00:00:00'),
#  Timestamp('1970-01-01 00:00:00'),
#  Timestamp('1970-01-01 00:00:00'),
# ...
